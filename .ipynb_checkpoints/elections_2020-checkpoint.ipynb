# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ##### Загрузка данных из data_fldr_name (файлы с расширением data_ext_name). Формирование таблиц df_yik(по УИКам) и df_tik(по ТИКам)

# %%
data_fldr_name = 'data'
data_ext_name = 'xlsx'

# %%
file_names_lst = [
    file_name
    for file_name in os.listdir(data_fldr_name) 
    if file_name.endswith('.' + data_ext_name)
]

tik_names_lst = [file_name.replace('.' + data_ext_name, '') for file_name in file_names_lst]

df_list = []
for file_name in file_names_lst:
    df = pd.read_excel(data_fldr_name + '/' + file_name).T
    df['ТИК'] = file_name.replace('.' + data_ext_name, '')
    df_list.append(df)
    
df_dict = dict(zip(tik_names_lst, df_list))

df_yik = pd.concat(df_list)

# %%
df_yik['УИК'] = df_yik.index
df_yik['УИК'] = df_yik['УИК'].map(lambda x: int(x.replace('УИК №', '')))
df_yik.sort_values(by=['УИК'], inplace=True)

# %%
df_yik.rename(columns={
    0: 'Число участников',
    1: 'Выданные бюллетени',
    2: 'Бюллетени в урнах',
    3: 'Недействительные бюллетени',
    4: 'Голосов за',
    5: 'Голосов против'}, inplace=True)

# %%
df_yik['Явка%'] = df_yik['Бюллетени в урнах'] / df_yik['Число участников'] * 100
df_yik['за%'] = df_yik['Голосов за'] / df_yik['Бюллетени в урнах'] * 100
df_yik['против%'] = df_yik['Голосов против'] / df_yik['Бюллетени в урнах'] * 100
df_yik.reset_index(inplace=True)

# %%
df_tik = df_yik \
    .groupby('ТИК', as_index=False)[['Число участников', 'Бюллетени в урнах', 'Голосов за', 'Голосов против']] \
    .sum()

# %%
df_tik['Явка%'] = df_tik['Бюллетени в урнах'] / df_tik['Число участников'] * 100
df_tik['за%'] = df_tik['Голосов за'] / df_tik['Бюллетени в урнах'] * 100
df_tik['против%'] = df_tik['Голосов против'] / df_tik['Бюллетени в урнах'] * 100

# %% [markdown]
# ##### График по всему региону

# %%
yavka_reg = df_tik['Бюллетени в урнах'].sum() / df_tik['Число участников'].sum() * 100
za_reg = df_tik['Голосов за'].sum() / df_tik['Бюллетени в урнах'].sum() * 100
protiv_reg = df_tik['Голосов против'].sum() / df_tik['Бюллетени в урнах'].sum() * 100
kol_yik_reg = df_yik.shape[0]

figure, axes = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(20,10))
axes.scatter(
    df_yik['Явка%'], 
    df_yik['за%'],
    c='r'
);
axes.scatter(
    df_yik['Явка%'], 
    df_yik['против%'],
    c='b');
axes.set_xlabel('Явка, %', fontsize=20);
axes.set_ylabel('Доля ЗА \ ПРОТИВ, %', fontsize=20);

axes.axvline(x=yavka_reg, ls='--', c='g');
axes.axhline(y=za_reg, ls='--', c='g');
axes.set_xlim(15, 100);
axes.set_ylim(0, 100);
axes.set_title(
    'Владимирская область, УИКов - {}\n явка - {}%, за - {}%, против - {}%'\
    .format(kol_yik_reg, round(yavka_reg, 2), round(za_reg, 2), round(protiv_reg, 2)),
    fontsize=20);
figure.savefig('plots/Владимирская область.png');

# %% [markdown]
# ##### ТИКи на фоне всего региона

# %% [raw]
# for tik_idx in range(df_tik.shape[0]):
#     figure, axes = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(20,10))
#
#     tik_name = df_tik.iloc[tik_idx]['ТИК']
#     df_cur_tik = df_yik[df_yik['ТИК'] == tik_name]
#     df_rest = df_yik[df_yik['ТИК'] != tik_name]
#
#     axes.scatter(
#         df_rest['Явка%'],
#         df_rest['за%'],
#         c='r',
#         marker='.'
#     );
#     axes.scatter(
#         df_rest['Явка%'],
#         df_rest['против%'],
#         c='b',
#         marker='.'
#     );
#
#     axes.scatter(
#         df_cur_tik['Явка%'],
#         df_cur_tik['за%'],
#         c='black',
#         marker='o'
#     );
#     axes.scatter(
#         df_cur_tik['Явка%'],
#         df_cur_tik['против%'],
#         c='black',
#         marker='o'
#     );
#
#     yavka = df_cur_tik['Бюллетени в урнах'].sum() / df_cur_tik['Число участников'].sum() * 100
#     za = df_cur_tik['Голосов за'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
#     protiv = df_cur_tik['Голосов против'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
#     kol_yik = df_cur_tik.shape[0]
#
#     axes.set_xlabel('Явка, %', fontsize=20);
#     axes.set_ylabel('Доля ЗА \ ПРОТИВ, %', fontsize=20);
#
#     axes.axvline(x=yavka_reg, ls='--', c='g');
#     axes.axhline(y=za_reg, ls='--', c='g');
#     axes.set_xlim(15, 100);
#     axes.set_ylim(0, 100);
#     axes.set_title(
#         '{} на фоне региона, УИКов - {}\n явка - {}%, за - {}%, против - {}%'\
#         .format(tik_name, kol_yik, round(yavka, 2), round(za, 2), round(protiv, 2)),
#         fontsize=15);
#     figure.savefig('plots/{}_на фоне региона.png'.format(tik_name));

# %% [markdown]
# ##### Выгрузка графиков по ТИКам в файлы

# %% [raw]
# for tik_idx in range(df_tik.shape[0]):
#     figure, axes = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(20,10))
#
#     tik_name = df_tik.iloc[tik_idx]['ТИК']
#     df_cur_tik = df_yik[df_yik['ТИК'] == tik_name]
#
#     axes.scatter(
#         df_cur_tik['Явка%'],
#         df_cur_tik['за%'],
#         c='r'
#     );
#     axes.scatter(
#         df_cur_tik['Явка%'],
#         df_cur_tik['против%'],
#         c='b');
#     axes.set_xlabel('Явка, %');
#     axes.set_ylabel('Доля ЗА \ ПРОТИВ, %');
#
#     yavka = df_cur_tik['Бюллетени в урнах'].sum() / df_cur_tik['Число участников'].sum() * 100
#     za = df_cur_tik['Голосов за'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
#     protiv = df_cur_tik['Голосов против'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
#     kol_yik = df_cur_tik.shape[0]
#
# #     axes.annotate(
# #         yavka[outliner_idx].index[0],
# #         (yavka[outliner_idx][0], za[outliner_idx][0]),
# #         fontsize=20
# #     );
#
#     axes.axvline(x=yavka, ls='--', c='g');
#     axes.axhline(y=za, ls='--', c='g');
#     axes.set_xlim(15, 100);
#     axes.set_ylim(0, 100);
#     axes.set_title(
#         '{}, УИКов - {}\n явка - {}%, за - {}%, против - {}%'\
#         .format(tik_name, kol_yik, round(yavka, 2), round(za, 2), round(protiv, 2)),
#         fontsize=15);
# #     figure.savefig('plots/{}.png'.format(tik_name));

# %% [markdown]
# ##### Графики по ТИКам в столбцах

# %%
plot_col_num = 2
figure, axes = plt.subplots(11, plot_col_num, sharex=True, sharey=True, figsize=(20,60))
for tik_idx in range(df_tik.shape[0]):
    tik_name = df_tik.iloc[tik_idx]['ТИК']
    df_cur_tik = df_yik[df_yik['ТИК'] == tik_name]
    
    plot_pos = (int(tik_idx / plot_col_num), tik_idx % plot_col_num)
    axes[plot_pos].scatter(
        df_cur_tik['Явка%'], 
        df_cur_tik['за%'],
        c='r'
    );
    axes[plot_pos].scatter(
        df_cur_tik['Явка%'], 
        df_cur_tik['против%'],
        c='b');
    axes[plot_pos].set_xlabel('Явка, %');
    axes[plot_pos].set_ylabel('Доля ЗА \ ПРОТИВ, %');
    
    yavka = df_cur_tik['Бюллетени в урнах'].sum() / df_cur_tik['Число участников'].sum() * 100
    za = df_cur_tik['Голосов за'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
    protiv = df_cur_tik['Голосов против'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
    kol_yik = df_cur_tik.shape[0]

    axes[plot_pos].axvline(x=yavka, ls='--', c='g');
    axes[plot_pos].axhline(y=za, ls='--', c='g');
    axes[plot_pos].set_xlim(15, 100);
    axes[plot_pos].set_ylim(0, 100);
    axes[plot_pos].set_title(
        '{}, УИКов - {}\n явка - {}%, за - {}%, против - {}%'\
        .format(tik_name, kol_yik, round(yavka, 2), round(za, 2), round(protiv, 2)),
        fontsize=15);
figure.savefig('plots/Единый.png'.format(tik_name));

# %% [markdown]
# ##### Размер точки в зависимости от количества бюллетеней в урнах

# %% [raw]
# for tik_idx in range(df_tik.shape[0]):
#     tik_name = df_tik.iloc[tik_idx]['ТИК']
#     df_cur_tik = df_yik[df_yik['ТИК'] == tik_name]
#
#     figure, axes = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(20,10))
#     sns.set(font_scale=2)
#     sns.scatterplot(
#         x='Явка%',
#         y='за%',
#         size='Бюллетени в урнах',
#         sizes=(20, 200),
#         hue='Бюллетени в урнах',
#         data=df_cur_tik,
#         ax=axes);
#
#     yavka = df_cur_tik['Бюллетени в урнах'].sum() / df_cur_tik['Число участников'].sum() * 100
#     za = df_cur_tik['Голосов за'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
#     protiv = df_cur_tik['Голосов против'].sum() / df_cur_tik['Бюллетени в урнах'].sum() * 100
#     kol_yik = df_cur_tik.shape[0]
#
#     axes.axvline(x=yavka, ls='--', c='g');
#     axes.axhline(y=za, ls='--', c='g');
#     axes.set_xlim(15, 100);
#     axes.set_ylim(0, 100);
#     axes.set_title(
#         '{}, УИКов - {}\n явка - {}%, за - {}%, против - {}%'\
#         .format(tik_name, kol_yik, round(yavka, 2), round(za, 2), round(protiv, 2)),
#         fontsize=20);
# #     figure.savefig('new_plots/{}.png'.format(tik_name));

# %% [markdown]
# ##### Интерактивный график Plotly

# %%
def plot_1(tik_name):
    df_cur_tik = df_yik[df_yik['ТИК'] == tik_name]

    fig = px.scatter(
            df_cur_tik, 
            x='Явка%', 
            y='за%',
            hover_data=['Бюллетени в урнах', 'index'],
            size='Бюллетени в урнах',
            color='Бюллетени в урнах',
            size_max=10,
            color_continuous_scale='Bluered_r')
    fig.show()

# %%
plot_1('Владимир')
# Out:
# <div>
#
#
#             <div id="11776de2-34d1-42f1-823f-4ab9a3f12cdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11776de2-34d1-42f1-823f-4ab9a3f12cdd")) {
#                     Plotly.newPlot(
#                         '11776de2-34d1-42f1-823f-4ab9a3f12cdd',
#                         [{"customdata": [[651, "\u0423\u0418\u041a \u2116345"], [703, "\u0423\u0418\u041a \u2116346"], [843, "\u0423\u0418\u041a \u2116347"], [678, "\u0423\u0418\u041a \u2116348"], [1020, "\u0423\u0418\u041a \u2116349"], [1593, "\u0423\u0418\u041a \u2116350"], [1430, "\u0423\u0418\u041a \u2116351"], [834, "\u0423\u0418\u041a \u2116352"], [2689, "\u0423\u0418\u041a \u2116353"], [765, "\u0423\u0418\u041a \u2116354"], [1419, "\u0423\u0418\u041a \u2116355"], [550, "\u0423\u0418\u041a \u2116356"], [536, "\u0423\u0418\u041a \u2116357"], [970, "\u0423\u0418\u041a \u2116358"], [1973, "\u0423\u0418\u041a \u2116359"], [1130, "\u0423\u0418\u041a \u2116360"], [981, "\u0423\u0418\u041a \u2116361"], [1856, "\u0423\u0418\u041a \u2116362"], [1896, "\u0423\u0418\u041a \u2116363"], [1472, "\u0423\u0418\u041a \u2116364"], [1162, "\u0423\u0418\u041a \u2116365"], [1696, "\u0423\u0418\u041a \u2116366"], [880, "\u0423\u0418\u041a \u2116367"], [591, "\u0423\u0418\u041a \u2116368"], [1982, "\u0423\u0418\u041a \u2116369"], [2053, "\u0423\u0418\u041a \u2116370"], [371, "\u0423\u0418\u041a \u2116371"], [872, "\u0423\u0418\u041a \u2116372"], [150, "\u0423\u0418\u041a \u2116373"], [667, "\u0423\u0418\u041a \u2116374"], [1250, "\u0423\u0418\u041a \u2116375"], [1175, "\u0423\u0418\u041a \u2116376"], [2458, "\u0423\u0418\u041a \u2116377"], [938, "\u0423\u0418\u041a \u2116378"], [1873, "\u0423\u0418\u041a \u2116379"], [1976, "\u0423\u0418\u041a \u2116380"], [717, "\u0423\u0418\u041a \u2116381"], [2040, "\u0423\u0418\u041a \u2116382"], [299, "\u0423\u0418\u041a \u2116383"], [1152, "\u0423\u0418\u041a \u2116384"], [780, "\u0423\u0418\u